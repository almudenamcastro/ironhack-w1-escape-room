# %% [markdown]
# ## Escape room

# %% [markdown]
# ### import functions and libraries

# %%
## Copy the updated functions file in the proper path

import gdown
#https://drive.google.com/file/d/11UHKeciDuAOvT2lTjYcZ0wFiVAcvvb-D/view?usp=sharing

url = 'https://drive.google.com/uc?id=11UHKeciDuAOvT2lTjYcZ0wFiVAcvvb-D'  # Reemplaza 'file_id' con el ID real del archivo
output = 'functionsb.py'  # Puedes especificar el nombre con el que quieres guardar el archivo
gdown.download(url, output, quiet=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-8e344389f042> in <cell line: 8>()
#       6 url = 'https://drive.google.com/uc?id=11UHKeciDuAOvT2lTjYcZ0wFiVAcvvb-D'  # Reemplaza 'file_id' con el ID real del archivo
#       7 output = 'functionsb.py'  # Puedes especificar el nombre con el que quieres guardar el archivo
# ----> 8 gdown.download(url, output, quiet=False)
#
# /usr/local/lib/python3.10/dist-packages/gdown/download.py in download(url, output, quiet, proxy, speed, use_cookies, verify, id, fuzzy, resume, format, user_agent, log_messages)
#     186
#     187     while True:
# --> 188         res = sess.get(url, stream=True, verify=verify)
#     189
#     190         if not (gdrive_file_id and is_gdrive_download_link):
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in get(self, url, **kwargs)
#     600
# ...

# %%
# make sure the functions file is automatically updated
# %load_ext autoreload
# %autoreload 2

# Connect Google Colab with Google Drive:
from google.colab import drive
drive.mount('/content/drive')
# Change the functions file Path
import sys
sys.path.append(r'/content/drive/MyDrive/Colab Notebooks/w1-escape-room')

from functions import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Generate objects

# %%
## Create the rooms
game_room = {
    "name": "game room",
    "type": "room",
}

bedroom_1 = {
    "name": "bedroom 1",
    "type": "room",
}

bedroom_2 = {
    "name": "bedroom 2",
    "type": "room",
}

living_room = {
    "name": "living room",
    "type": "room",
}

outside = {
  "name": "outside"
}

## Create the doors
door_a = {
      "name": "door a",
      "type": "door",
}
door_b = {
      "name": "door b",
      "type": "door",
}
door_c = {
      "name": "door c",
      "type": "door",
}
door_d = {
      "name": "door d",
      "type": "door",
}

## Create the keys

key_a = {
    "name": "key for door a",
    "type": "key",
    "target": door_a,
}

key_b = {
    "name": "key for door b",
    "type": "key",
    "target": door_b,
}
key_c = {
    "name": "key for door c",
    "type": "key",
    "target": door_c,
}
key_d = {
    "name": "key for door d",
    "type": "key",
    "target": door_d,
}


## Create the furniture

couch = {
    "name": "couch",
    "type": "furniture",
}

piano = {
    "name": "piano",
    "type": "furniture"
}

queen_bed = {
    "name": "queen bed",
    "type": "furniture"
}

double_bed = {
    "name": "double bed",
    "type": "furniture"
}

dresser = {
    "name": "dresser",
    "type": "furniture"
}

dining_table = {
    "name": "dinning table",
    "type": "furniture"
}

## Create lists

all_rooms = [game_room, bedroom_1, bedroom_2, living_room]

all_doors = [door_a, door_b, door_c, door_d]

all_keys = [key_a, key_b, key_c, key_d]

## Initial object relations

INIT_OBJECT_RELATIONS = {
    "game room": [couch, piano, door_a],
    "bedroom 1": [queen_bed, door_b, door_c],
    "bedroom 2": [double_bed, dresser, door_b],
    "living room": [dining_table, dresser, door_c, door_d],
    "piano": [key_a],
    "queen bed": [key_b],
    "double bed": [key_c],
    "dresser": [key_d],
    "door a": [game_room, bedroom_1],
    "door b": [bedroom_1, bedroom_2],
    "door c": [bedroom_1, living_room],
    "door d": [living_room, outside],
    "outside": [door_d],
}

## Initial game state
INIT_GAME_STATE = {
    "current_room": game_room,
    "keys_collected": [],
    "target_room": outside
}

## When a new game begins, we restart the state and the object relations

game_state = INIT_GAME_STATE.copy()
object_relations = INIT_OBJECT_RELATIONS.copy()

# %% [markdown]
# ## play

# %%
start_game(game_state, object_relations)
# Out:
# You wake up on a couch and find yourself in a strange house with no windows which you have never been to before.
# You don't remember why you are here and what had happened before.
# You feel some unknown danger is approaching.
# You must SCAPE, NOW!
#
#
#
#
# You are now in the game room
# What would you like to do? Type 'explore' or 'examine'? explore
# In the game room, you find: couch, piano, door a
# What would you like to examine? couch
# You examine couch. There isn't anything interesting about it.
# What would you like to examine? pian
# You examine piano. You find key for door a.
# What would you like to examine? door
# You examine door a. You unlock it with a key you have.
#
#
# You are now in the bedroom 1
# What would you like to do? Type 'explore' or 'examine'? explore
# In the bedroom 1, you find: queen bed, door b, door c
# What would you like to examine? bed
# You examine queen bed. You find key for door b.
# What would you like to examine? oso panda
# ...
